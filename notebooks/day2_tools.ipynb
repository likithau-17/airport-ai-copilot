# %% [markdown]
# # Day 2 — Operational Tools
#
# Airport Operations AI Copilot: synthetic telemetry, operational metrics, driver incentives, and surge override tools.

# %%
from src.tools import get_airport_metrics

for airport in ['SFO', 'LAX', 'JFK']:
    print(get_airport_metrics(airport))

# %%
from src.tools import calculate_driver_incentive

result = calculate_driver_incentive(
    airport_code='SFO',
    active_drivers=40,
    request_volume=120,
    queue_size=70,
)

print(result)

# %%
from src.tools import trigger_surge_override

print(trigger_surge_override('SFO', 1.2))
print(trigger_surge_override('SFO', 1.5))
print(trigger_surge_override('SFO', 2.1))
